# %%
import httpx

# %%
BASE_URL = "http://127.0.0.1:8000"

health_resp = httpx.get(f"{BASE_URL}/health")
health_resp.json()

# %% [markdown]
# ### 注册

# %%
auth_register_resp = httpx.post(f"{BASE_URL}/api/auth/register", json={
    "username": "limingxuan2",
    "password": "Li314159_",
    "nickname": "1"
})
auth_register_resp.json()
# Out:
# {'code': 10400, 'msg': '用户名已存在', 'data': None}

# %% [markdown]
# ### 登录

# %%
login_resp = httpx.post(
    f"{BASE_URL}/api/auth/login",
    json={"username": "limingxuan2", "password": "Li314159_"},
)
login_data = login_resp.json()
login_data
# Out:
# {'code': 10000,
#  'msg': '登录成功',
#  'data': {'nickname': '1',
#   'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJjOTM4YmU4YS1mZGFlLTRkNTItYjM0Yy1mODE2MWU2NWMzNTMiLCJpYXQiOjE3NzUwOTMzNDIsImV4cCI6MTc3NTY5ODE0MiwidG9rZW5fdmVyc2lvbiI6MH0.F7aGzgzeAXOwqS1stXAE5XKDkIISLO-BkMqqxhgDaCI'}}

# %%
session = httpx.Client(base_url=BASE_URL)
session.headers.update({"Authorization": f"Bearer {login_data["data"]["access_token"]}"})
# session.headers.update({"Authorization": f"Bearer fake_token"})

# %% [markdown]
# ### 获取个人信息

# %%
uesr_me_resp = session.get(f"/api/user/me")
uesr_me_resp.json()
# Out:
# {'code': 10000,
#  'msg': 'ok',
#  'data': {'user_id': 'c938be8a-fdae-4d52-b34c-f8161e65c353',
#   'username': 'limingxuan2',
#   'nickname': '1',
#   'created_at': '2026-04-01T15:50:53.294989+00:00'}}
