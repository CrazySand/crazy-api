# %%
import httpx

# %%
BASE_URL = "http://127.0.0.1:8000"

health_resp = httpx.get(f"{BASE_URL}/health")
health_resp.json()
# Out:
# {'code': 10000, 'msg': '服务正常', 'data': None}

# %% [markdown]
# ### 注册

# %%
auth_register_resp = httpx.post(f"{BASE_URL}/api/auth/register", json={
    "username": "limingxuan",
    "password": "12345678",
    "nickname": "黎明轩"
})
auth_register_resp.json()
# Out:
# {'code': 10400, 'msg': '用户名已存在', 'data': None}

# %% [markdown]
# ### 登录

# %%
login_resp = httpx.post(
    f"{BASE_URL}/api/auth/login",
    json={"username": "limingxuan", "password": "12345678"},
)
login_data = login_resp.json()
login_data
# Out:
# {'code': 10000,
#  'msg': '登录成功',
#  'data': {'nickname': '黎明轩',
#   'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiIwMTI0NmMxZi0yZjUzLTQzM2EtODFlZi03NjhmN2Y0NTkzZjAiLCJpYXQiOjE3NzY0MjUxNzMsImV4cCI6MTc3NzAyOTk3MywidG9rZW5fdmVyc2lvbiI6MH0.D6ecppVNclMuSnCatAhaZJPeaT5jO8qR29ws0bKNLi0'}}

# %%
session = httpx.Client(base_url=BASE_URL)
session.headers.update({"Authorization": f"Bearer {login_data["data"]["access_token"]}"})
# session.headers.update({"Authorization": f"Bearer fake_token"})

# %% [markdown]
# ### 获取个人信息

# %%
uesr_me_resp = session.get("/api/user/me")
uesr_me_resp.json()
# Out:
# {'code': 10000,
#  'msg': '获取成功',
#  'data': {'user_id': '01246c1f-2f53-433a-81ef-768f7f4593f0',
#   'username': 'limingxuan',
#   'nickname': '黎明轩',
#   'created_at': '2026-04-17T10:56:16.522926+00:00'}}
