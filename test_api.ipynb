# %%
import httpx

# %%
BASE_URL = "http://127.0.0.1:8000"

health_resp = httpx.get(f"{BASE_URL}/health")
health_resp.json()
# Out:
# {'code': 10000, 'msg': '服务正常', 'data': None}

# %% [markdown]
# ### 注册

# %%
auth_register_resp = httpx.post(f"{BASE_URL}/api/auth/register", json={
    "username": "limingxuan",
    "password": "12345678",
    "nickname": "黎明轩"
})
auth_register_resp.json()
# Out:
# {'code': 10000,
#  'msg': '注册成功',
#  'data': {'user_id': 'eadf8aa8-abd6-43de-9bfb-821f65d52785',
#   'username': 'limingxuan',
#   'nickname': '黎明轩'}}

# %% [markdown]
# ### 登录

# %%
login_resp = httpx.post(
    f"{BASE_URL}/api/auth/login",
    json={"username": "limingxuan", "password": "12345678" * 100000000},
)
login_data = login_resp.json()
login_data
# Out:
# ---------------------------------------------------------------------------
# ReadTimeout                               Traceback (most recent call last)
# File ~/miniconda3/envs/crazysand/lib/python3.12/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/miniconda3/envs/crazysand/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/miniconda3/envs/crazysand/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
# ...

# %%
session = httpx.Client(base_url=BASE_URL)
session.headers.update({"Authorization": f"Bearer {login_data["data"]["access_token"]}"})
# session.headers.update({"Authorization": f"Bearer fake_token"})

# %% [markdown]
# ### 获取个人信息

# %%
uesr_me_resp = session.get("/api/user/me")
uesr_me_resp.json()
# Out:
# {'code': 10000,
#  'msg': '获取成功',
#  'data': {'user_id': 'eadf8aa8-abd6-43de-9bfb-821f65d52785',
#   'username': 'limingxuan',
#   'nickname': '黎明轩',
#   'created_at': '2026-06-10T11:06:27.913346+00:00'}}
