# %%
import requests

# %%
BASE_URL = "http://127.0.0.1:8000"

resp = requests.get(f"{BASE_URL}/health")
resp.json()
# Out:
# {'code': 10000, 'msg': 'ok', 'data': None}

# %% [markdown]
# ### 注册

# %%
resp = requests.post(f"{BASE_URL}/api/auth/register", json={
    "username": "limingxuan2",
    "password": "Li314159_",
    "nickname": "1"
})
resp.json()
# Out:
# {'code': 10400, 'msg': '用户名已存在', 'data': None}

# %% [markdown]
# ### 登录

# %%
login_resp = requests.post(
    f"{BASE_URL}/api/auth/login",
    json={"username": "limingxuan2", "password": "Li314159_"},
)
login_data = login_resp.json()
login_data
# Out:
# {'code': 10000,
#  'msg': '登录成功',
#  'data': {'nickname': '1',
#   'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJjOTM4YmU4YS1mZGFlLTRkNTItYjM0Yy1mODE2MWU2NWMzNTMiLCJpYXQiOjE3NzUwNzg1MTMsImV4cCI6MTc3NTY4MzMxMywidG9rZW5fdmVyc2lvbiI6MH0.SCInfTmTiWYSRvhmsnGsUzplpJBkHyq4l_qsYq8pDtM'}}

# %%
session = requests.Session()
session.headers.update({"Authorization": f"Bearer {login_data["data"]["access_token"]}"})
# session.headers.update({"Authorization": f"Bearer fake_token"})

# %% [markdown]
# ### 获取个人信息

# %%
resp = session.get(f"{BASE_URL}/api/user/me")
resp.json()
# Out:
# {'code': 10000,
#  'msg': 'ok',
#  'data': {'user_id': 'c938be8a-fdae-4d52-b34c-f8161e65c353',
#   'username': 'limingxuan2',
#   'nickname': '1',
#   'created_at': '2026-04-01T15:50:53.294989+00:00'}}
